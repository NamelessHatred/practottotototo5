# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой

df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.head() #Для получения первых n строк дата-сета используется метод head(n). По умолчанию возвращается пять первых строк.
#Вывод: вывел информацию о пяти первых строках из датасета элементов.
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08     0.04    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02     0.04    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33     0.04    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.shape #выводит размерность массива
# Out:
# (7999, 21)

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.columns #выводит наименование всех колонок
# Out:
# Index(['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
#        'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
#        'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
#        'silver', 'uranium', 'is_safe'],
#       dtype='object')

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.nunique() #выводит все уникальные значения
# Out:
# aluminium       495
# ammonia        2564
# arsenic         107
# barium          480
# cadmium          23
# chloramine      812
# chromium         91
# copper          201
# flouride        151
# bacteria        101
# viruses          61
# lead            200
# nitrates       1803
# nitrites        280
# mercury          11
# perchlorate    2999
# radium          735
# selenium         11
# silver           51
# uranium          10
# is_safe           3
# dtype: int64

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.sort_values(by='aluminium') #сортирует по колонке "aluminium"
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 3386       0.00   28.45     0.53    3.79     0.10        6.34      0.88
# 6126       0.00   23.15     0.01    0.92     0.01        0.27      0.02
# 6120       0.00   22.07     0.02    0.06     0.01        0.10      0.05
# 4255       0.00    7.09     0.03    0.04     0.06        0.18      0.04
# 7447       0.00    8.39     0.03    0.51     0.08        0.02      0.01
# ...         ...     ...      ...     ...      ...         ...       ...
# 1490       5.01   19.29     0.65    3.45     0.03        1.82      0.64
# 1831       5.03    7.38     0.66    4.21     0.10        1.31      0.81
# 1501       5.03   26.11     0.06    1.09     0.04        6.07      0.73
# 1613       5.03    7.59     0.13    0.94     0.04        3.22      0.19
# 1167       5.05   19.35     0.28    2.90     0.05        1.02      0.19
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.drop(columns = ["arsenic"]) #удаляет всю колонку под название "arsenic"
# Out:
#       aluminium ammonia  barium  cadmium  chloramine  chromium  copper  \
# 0          1.65    9.08    2.85    0.007        0.35      0.83    0.17
# 1          2.32   21.16    3.31    0.002        5.28      0.68    0.66
# 2          1.01   14.02    0.58    0.008        4.24      0.53    0.02
# 3          1.36   11.33    2.96    0.001        7.23      0.03    1.66
# 4          0.92   24.33    0.20    0.006        2.67      0.69    0.57
# ...         ...     ...     ...      ...         ...       ...     ...
# 7994       0.05    7.78    1.95    0.040        0.10      0.03    0.03
# 7995       0.05   24.22    0.59    0.010        0.45      0.02    0.02
# 7996       0.09    6.85    0.61    0.030        0.05      0.05    0.02
# 7997       0.01      10    2.00    0.000        2.00      0.00    0.09
# 7998       0.04    6.85    0.70    0.030        0.05      0.01    0.03
#
#       flouride  bacteria  viruses   lead  nitrates  nitrites  mercury  \
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df=df.replace({"arsenic":0.04}, "Unknown") #Заменяет значения, равные 0.04 на Unknown
df.head() #выводит таблицу, показывая уже изменённый стобец "arsenic"
# Out:
#    aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  copper  \
# 0       1.65    9.08  Unknown    2.85    0.007        0.35      0.83    0.17
# 1       2.32   21.16     0.01    3.31    0.002        5.28      0.68    0.66
# 2       1.01   14.02  Unknown    0.58    0.008        4.24      0.53    0.02
# 3       1.36   11.33  Unknown    2.96    0.001        7.23      0.03    1.66
# 4       0.92   24.33     0.03    0.20    0.006        2.67      0.69    0.57
#
#    flouride  bacteria  ...   lead  nitrates  nitrites  mercury  perchlorate  \
# 0      0.05      0.20  ...  0.054     16.08      1.13    0.007        37.75
# 1      0.90      0.65  ...  0.100      2.01      1.93    0.003        32.26
# 2      0.99      0.05  ...  0.078     14.16      1.11    0.006        50.28
# 3      1.08      0.71  ...  0.016      1.41      1.29    0.004         9.12
# 4      0.61      0.13  ...  0.117      6.74      1.11    0.003        16.90
#
#    radium  selenium  silver  uranium  is_safe
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.drop_duplicates() #Удаляет дубликаты
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.info() #info() в библиотеке Pandas используется для получения общей информации о DataFrame, включая количество непустых значений, типы данных в каждом столбце и объем потребляемой памяти.
#Вывод: используя эту функцию, вывел:
#-Количество непустых значений в каждом столбце.
#-Тип данных каждого столбца.
#-Общее количество столбцов.
#-Количество использованной памяти.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7999 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7999 non-null   float64
#  1   ammonia      7999 non-null   object
#  2   arsenic      7999 non-null   float64
#  3   barium       7999 non-null   float64
#  4   cadmium      7999 non-null   float64
#  5   chloramine   7999 non-null   float64
#  6   chromium     7999 non-null   float64
#  7   copper       7999 non-null   float64
#  8   flouride     7999 non-null   float64
#  9   bacteria     7999 non-null   float64
#  10  viruses      7999 non-null   float64
#  11  lead         7999 non-null   float64
#  12  nitrates     7999 non-null   float64
#  13  nitrites     7999 non-null   float64
#  14  mercury      7999 non-null   float64
#  15  perchlorate  7999 non-null   float64
#  16  radium       7999 non-null   float64
#  17  selenium     7999 non-null   float64
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
df.describe() #Функция возвращает основные статистические показатели для каждого числового столбца датасета элементов.
#Вывели показатели таблицы с помощью describe(), такие как количество, среднее значение, стандартное отклонение, минимальное и максимальное значения, медиана и квартили.
# Out:
#          aluminium      arsenic       barium      cadmium   chloramine  \
# count  7999.000000  7999.000000  7999.000000  7999.000000  7999.000000
# mean      0.666158     0.161445     1.567715     0.042806     2.176831
# std       1.265145     0.252590     1.216091     0.036049     2.567027
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.040000     0.030000     0.560000     0.008000     0.100000
# 50%       0.070000     0.050000     1.190000     0.040000     0.530000
# 75%       0.280000     0.100000     2.480000     0.070000     4.240000
# max       5.050000     1.050000     4.940000     0.130000     8.680000
#
#           chromium       copper     flouride     bacteria      viruses  \
# count  7999.000000  7999.000000  7999.000000  7999.000000  7999.000000
# mean      0.247226     0.805857     0.771565     0.319665     0.328583
# std       0.270640     0.653539     0.435373     0.329485     0.378096
# ...

# %%
import pandas as dp #импорт pandas для того чтобы работать с этой библиотекой
df = dp.read_csv('waterQuality1.csv') #читает таблицу/файл
row_data = df.loc[0] #проводит выборку данных по строкам и столбцам
print(row_data) #выводит выборку данных
# Out:
# aluminium       1.65
# ammonia         9.08
# arsenic         0.04
# barium          2.85
# cadmium        0.007
# chloramine      0.35
# chromium        0.83
# copper          0.17
# flouride        0.05
# bacteria         0.2
# viruses          0.0
# lead           0.054
# nitrates       16.08
# nitrites        1.13
# mercury        0.007
# perchlorate    37.75
# radium          6.78
# selenium        0.08
# silver          0.34
# uranium         0.02
# is_safe            1
# Name: 0, dtype: object
